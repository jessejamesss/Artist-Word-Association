# %%
import pandas as pd
import json

with open('data.json') as f:
    data = json.load(f)

df = pd.DataFrame(data)

# %%
print(df)
# Out:
#                             created_at                   id  \
# 0       Tue Nov 08 15:26:13 +0000 2022  1590002758765400064
# 1       Mon Nov 07 23:41:37 +0000 2022  1589765042194771969
# 2       Mon Nov 07 17:21:51 +0000 2022  1589669473979883522
# 3       Mon Nov 07 02:46:22 +0000 2022  1589449150978207744
# 4       Sun Nov 06 03:19:02 +0000 2022  1589094982795038720
# ...                                ...                  ...
# 385118  Thu May 30 23:03:23 +0000 2013   340242063016726528
# 385119  Wed May 29 23:03:17 +0000 2013   339879649855291394
# 385120  Wed May 29 20:25:08 +0000 2013   339839849181888513
# 385121  Tue May 28 23:02:52 +0000 2013   339517155244650498
# 385122  Tue May 28 05:40:23 +0000 2013   339254807602819072
#
#                      id_str  \
# 0       1590002758765400064
# 1       1589765042194771969
# 2       1589669473979883522
# 3       1589449150978207744
# 4       1589094982795038720
# ...                     ...
# 385118   340242063016726528
# ...

# %%
# for col in df.columns:
#     print(col)
deleteddf = df.drop(['in_reply_to_status_id',
    'in_reply_to_status_id_str',
    'in_reply_to_user_id',
    'in_reply_to_user_id_str',
    'in_reply_to_screen_name'], axis=1)
print(deleteddf)
# Out:
#                             created_at                   id  \
# 0       Tue Nov 08 15:26:13 +0000 2022  1590002758765400064
# 1       Mon Nov 07 23:41:37 +0000 2022  1589765042194771969
# 2       Mon Nov 07 17:21:51 +0000 2022  1589669473979883522
# 3       Mon Nov 07 02:46:22 +0000 2022  1589449150978207744
# 4       Sun Nov 06 03:19:02 +0000 2022  1589094982795038720
# ...                                ...                  ...
# 385118  Thu May 30 23:03:23 +0000 2013   340242063016726528
# 385119  Wed May 29 23:03:17 +0000 2013   339879649855291394
# 385120  Wed May 29 20:25:08 +0000 2013   339839849181888513
# 385121  Tue May 28 23:02:52 +0000 2013   339517155244650498
# 385122  Tue May 28 05:40:23 +0000 2013   339254807602819072
#
#                      id_str  \
# 0       1590002758765400064
# 1       1589765042194771969
# 2       1589669473979883522
# 3       1589449150978207744
# 4       1589094982795038720
# ...                     ...
# 385118   340242063016726528
# ...
